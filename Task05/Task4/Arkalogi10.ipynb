# %%
import pandas as pd


d= {0: {
    'underlying': 'NIFTY50',
    'symbol': 'APOLLOHOSP',
    'side': 'BUY',
    'entry_date': 240101,
    'exit_date': 240101,
    'entry_time': '13:30',
    'exit_time': '14:00',
    'entry_price': 5724.5,
    'exit_price': 5742.05,
    'qty': 100,
    'pnl': 1755.0,
    'entry_support': 5710.0,
    'entry_resistance': 5742.05,
    'entry_support_distance%': 0.25,
    'entry_resistance_distance%': 0.31,
    'exit_reason': 'Target hitted'
  },
  1: {
    'underlying': 'NIFTY50',
    'symbol': 'BEL',
    'side': 'BUY',
    'entry_date': 240101,
    'exit_date': 240101,
    'entry_time': '13:30',
    'exit_time': '14:00',
    'entry_price': 112.0,
    'exit_price': 113.0,
    'qty': 1000,
    'pnl': 1000.0,
    'entry_support': 111.0,
    'entry_resistance': 113.0,
    'entry_support_distance%': 0.90,
    'entry_resistance_distance%': 0.88,
    'exit_reason': 'Target hitted'
  },
    2: {    
    'underlying': 'NIFTY50',
    'symbol': 'HDFCBANK',
    'side': 'BUY',
    'entry_date': 240101,
    'exit_date': 240101,
    'entry_time': '13:30',
    'exit_time': '14:00',
    'entry_price': 1670.0,
    'exit_price': 1675.0,   
    'qty': 100,
    'pnl': 500.0,
    'entry_support': 1665.0,
    'entry_resistance': 1675.0,
    'entry_support_distance%': 0.30,
    'entry_resistance_distance%': 0.30,
    'exit_reason': 'Target hitted'
    },
     3: {
    'underlying': 'NIFTY50',
    'symbol': 'TATAMOTORS',
    'side': 'BUY',
    'entry_date': 240101,
    'exit_date': 240101,
    'entry_time': '13:30',
    'exit_time': '14:00',
    'entry_price': 600.0,
    'exit_price': 605.0,
    'qty': 100,
    'pnl': 500.0,
    'entry_support': 595.0,
    'entry_resistance': 605.0,
    'entry_support_distance%': 0.84,
    'entry_resistance_distance%': 0.83,
    'exit_reason': 'Target hitted'
    },
     4: {
    'underlying': 'NIFTY50',
    'symbol': 'INFY',
    'side': 'BUY',
    'entry_date': 240101,
    'exit_date': 240101,
    'entry_time': '13:30',
    'exit_time': '14:00',
    'entry_price': 1500.0,
    'exit_price': 1510.0,
    'qty': 100,
    'pnl': 1000.0,
    'entry_support': 1495.0,
    'entry_resistance': 1510.0,
    'entry_support_distance%': 0.33,
    'entry_resistance_distance%': 0.66, 
    'exit_reason': 'Target hitted'
    },
     5: {
    'underlying': 'NIFTY50',
    'symbol': 'RELIANCE',
    'side': 'BUY',
    'entry_date': 240101,
    'exit_date': 240101,
    'entry_time': '13:30',
    'exit_time': '14:00',
    'entry_price': 2500.0,
    'exit_price': 2520.0,
    'qty': 100,
    'pnl': 2000.0,
    'entry_support': 2490.0,
    'entry_resistance': 2520.0,
    'entry_support_distance%': 0.40,
    'entry_resistance_distance%': 0.60,
    'exit_reason': 'Target hitted'
    }, 
     6: {    
    'underlying': 'NIFTY50',
    'symbol': 'TCS',
    'side': 'BUY',
    'entry_date': 240101,
    'exit_date': 240101,
    'entry_time': '13:30',
    'exit_time': '14:00',
    'entry_price': 3500.0,
    'exit_price': 3520.0,
    'qty': 100,
    'pnl': 2000.0,
    'entry_support': 3480.0,
    'entry_resistance': 3520.0,
    'entry_support_distance%': 0.57,
    'entry_resistance_distance%': 0.57,
    'exit_reason': 'Target hitted'
    },
     7: {
    'underlying': 'NIFTY50',
    'symbol': 'HINDUNILVR',
    'side': 'BUY',
    'entry_date': 240101,
    'exit_date': 240101,
    'entry_time': '13:30',
    'exit_time': '14:00',
    'entry_price': 2500.0,
    'exit_price': 2520.0,
    'qty': 100,
    'pnl': 2000.0,
    'entry_support': 2490.0,
    'entry_resistance': 2520.0,
    'entry_support_distance%': 0.40,
    'entry_resistance_distance%': 0.60,
    'exit_reason': 'Target hitted'
    }

}

df = pd.DataFrame(d)
print(df)
# Out:
#                                         0              1              2  \
# underlying                        NIFTY50        NIFTY50        NIFTY50
# symbol                         APOLLOHOSP            BEL       HDFCBANK
# side                                  BUY            BUY            BUY
# entry_date                         240101         240101         240101
# exit_date                          240101         240101         240101
# entry_time                          13:30          13:30          13:30
# exit_time                           14:00          14:00          14:00
# entry_price                        5724.5          112.0         1670.0
# exit_price                        5742.05          113.0         1675.0
# qty                                   100           1000            100
# pnl                                1755.0         1000.0          500.0
# entry_support                      5710.0          111.0         1665.0
# ...
